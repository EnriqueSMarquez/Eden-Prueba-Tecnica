# %%
import pandas as pd

df_metadata = pd.read_csv("../dataset/dataset_scenario_3.csv")
df_metadata.head()
# Out:
#                                 user_id                              study_id  \
# 0  3035ae19-4e74-4ee0-917a-d36a68048e5a  00000408-a564-42e9-93a3-542379c9efc4
# 1  3035ae19-4e74-4ee0-917a-d36a68048e5a  00000408-a564-42e9-93a3-542379c9efc4
# 2  3035ae19-4e74-4ee0-917a-d36a68048e5a  00000408-a564-42e9-93a3-542379c9efc4
# 3  e4d463a6-4150-448d-b713-794c129deeaf  00013ba0-c32c-49d0-97e3-613eead4773e
# 4  e4d463a6-4150-448d-b713-794c129deeaf  00013ba0-c32c-49d0-97e3-613eead4773e
#
#                       study_description modalities  \
# 0  AP Y LAT DE COLUMNA LUMBAR/ TORAX PA         CR
# 1  AP Y LAT DE COLUMNA LUMBAR/ TORAX PA         CR
# 2  AP Y LAT DE COLUMNA LUMBAR/ TORAX PA         CR
# 3                         TORAX,COLUMNA         CR
# 4                         TORAX,COLUMNA         CR
#
#                               series_id  \
# 0  15a0b9df-0365-4490-b2be-a342bce8ce03
# 1  b1297501-3504-4608-9a0f-45771ce426af
# 2  ba89ba80-8f8d-46e2-8a5f-2a38e4f6dff8
# ...

# %%
df_metadata["report_id"].value_counts()
# Out:
# report_id
# 1d256604-4e52-44e0-bbd8-78518779cce1    8
# dbfe5f6e-74ce-4d58-b18f-9c61e1c414e1    3
# 9b494824-9e40-4163-a673-12ef33c56b4a    3
# a735310a-9306-4735-a0ad-7580fa2e0018    3
# 5f9ebce4-a376-4d22-bacf-fa99b74d3f8b    3
# ee3d3979-2990-470e-b0ff-fd37bf73e1d8    3
# dbe8c51b-a729-462e-8631-8609c5d165ad    2
# eefed9f5-e34f-438d-8170-300669a00bd5    2
# 51b3e5ba-6468-4735-931b-aebdadb0c189    2
# 92d06962-879d-4042-86c2-36fad56e8035    2
# Name: count, dtype: int64

# %%
# 10 studies en total

# %%
from src.utils.html_handling import clean_html
# Checking all rows of same report have the same diagnostic
last_text = ""
for i, text in df_metadata.loc[df_metadata["report_id"] == "1d256604-4e52-44e0-bbd8-78518779cce1", "field_value"].apply(clean_html).items():
    print(i)
    print(last_text == text)
    last_text = text
# Out:
# 8
# False
# 9
# True
# 10
# True
# 11
# True
# 12
# True
# 13
# True
# 14
# True
# 15
# True

# %%
results_df_multiple_images = pd.read_csv("../dataset_generated_plus_comparison5.csv")
results_df_one_image = pd.read_csv("../dataset_generated_plus_comparison_one_random_image5.csv")

# %%
results_df_multiple_images = results_df_multiple_images.dropna(subset=["metric1_json_result"]).reset_index(drop=True)
results_df_one_image = results_df_one_image.dropna(subset=["metric1_json_result"]).reset_index(drop=True)

# %%
import json
results_df_multiple_images["metric1_clinical_accuracy"] = results_df_multiple_images["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["clinical_accuracy_status"])
results_df_multiple_images["metric1_score"]= results_df_multiple_images["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["score"])
results_df_multiple_images["metric1_missed_findings"]= results_df_multiple_images["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["missed_findings"])
results_df_multiple_images["metric1_hallucinations"]= results_df_multiple_images["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["hallucinations"])

# %%
results_df_one_image["metric1_clinical_accuracy"] = results_df_one_image["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["clinical_accuracy_status"])
results_df_one_image["metric1_score"]= results_df_one_image["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["score"])
results_df_one_image["metric1_missed_findings"]= results_df_one_image["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["missed_findings"])
results_df_one_image["metric1_hallucinations"]= results_df_one_image["metric1_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["hallucinations"])

# %%
results_df_multiple_images["metric1_clinical_accuracy"].value_counts()
# Out:
# metric1_clinical_accuracy
# MINOR_ERROR       4
# CORRECT           4
# CRITICAL_ERROR    2
# Name: count, dtype: int64

# %%
results_df_one_image["metric1_clinical_accuracy"].value_counts()
# Out:
# metric1_clinical_accuracy
# CRITICAL_ERROR    6
# CORRECT           3
# MINOR_ERROR       1
# Name: count, dtype: int64

# %%
results_df_multiple_images["metric2_clinical_accuracy"] = results_df_multiple_images["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["clinical_accuracy_status"])
results_df_multiple_images["metric2_score"]= results_df_multiple_images["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["score"])
results_df_multiple_images["metric2_missed_findings"]= results_df_multiple_images["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["missed_findings"])
results_df_multiple_images["metric2_hallucinations"]= results_df_multiple_images["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["hallucinations"])

# %%
results_df_one_image["metric2_clinical_accuracy"] = results_df_one_image["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["clinical_accuracy_status"])
results_df_one_image["metric2_score"]= results_df_one_image["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["score"])
results_df_one_image["metric2_missed_findings"]= results_df_one_image["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["missed_findings"])
results_df_one_image["metric2_hallucinations"]= results_df_one_image["metric2_json_result"].apply(lambda x: json.loads(x.replace("json","").replace("```", ""))["hallucinations"])

# %%
results_df_multiple_images["metric2_clinical_accuracy"].value_counts()
# Out:
# metric2_clinical_accuracy
# CORRECT           5
# CRITICAL_ERROR    4
# MINOR_ERROR       1
# Name: count, dtype: int64

# %%
results_df_one_image["metric2_clinical_accuracy"].value_counts()
# Out:
# metric2_clinical_accuracy
# CRITICAL_ERROR    7
# CORRECT           2
# MINOR_ERROR       1
# Name: count, dtype: int64
